# %%
import pandas as pd

# %%
import numpy as np

# %%
print('hello')
# Out:
# hello

# %%
df = pd.read_csv('/Users/dadsgift/Downloads/LnT_Helmet_Survey_Raw.csv')

# %%
df.head()
# Out:
#    Respondent_ID            Name   Age Gender  Place         Date  \
# 0            1.0    Govind Yadav  19.0       M    DTU  10/12/2024
# 1            2.0          Bhavya  20.0       M    DTU  10/12/2024
# 2            3.0  Abhishek Kumar  21.0       M    DTU  11/12/2024
# 3            4.0         Gupreet  20.0       M    DTU  10/12/2024
# 4            5.0    Mayank Yadav  21.0       M    DTU  10/12/2024
#
#     Safety_Device Helemt_Frequency Most_Vulnerable_User ISI_Awareness  \
# 0             NaN           Always          Two Wheeler            No
# 1  Quality Helmet         Sometime          Two Wheeler            No
# 2  Quality Helmet           Always          Two Wheeler            No
# 3  Quality Helmet           Always          Two Wheeler            No
# 4             NaN           Always          Two Wheeler            No
#
#   Youth_Role Speed_Limit_Knowledge Helmet_Prevention_belief  \
# 0        Yes               25 KMPH                       No
# ...

# %%
df.shape
# Out:
# (46, 19)

# %%
df.columns
# Out:
# Index(['Respondent_ID', 'Name', 'Age', 'Gender ', 'Place ', 'Date',
#        'Safety_Device', 'Helemt_Frequency', 'Most_Vulnerable_User',
#        'ISI_Awareness', 'Youth_Role', 'Speed_Limit_Knowledge',
#        'Helmet_Prevention_belief', 'Helmet_Buying_Factor', 'Pillion_Helmet',
#        'Mirror_Importance', 'Helmet_Type', 'Influenced_Others',
#        'Media_Influence'],
#       dtype='object')

# %%
df.info
# Out:
# <bound method DataFrame.info of     Respondent_ID             Name   Age Gender  Place         Date  \
# 0             1.0     Govind Yadav  19.0       M    DTU  10/12/2024
# 1             2.0           Bhavya  20.0       M    DTU  10/12/2024
# 2             3.0   Abhishek Kumar  21.0       M    DTU  11/12/2024
# 3             4.0          Gupreet  20.0       M    DTU  10/12/2024
# 4             5.0     Mayank Yadav  21.0       M    DTU  10/12/2024
# 5             6.0          Nikshep  23.0       M    DTU  10/12/2024
# 6             7.0  Shashank Chabey  22.0       M    DTU  11/12/2024
# 7             8.0           Tushar  21.0       M    DTU  11/12/2024
# 8             9.0           Kalash  23.0       M    DTU  11/12/2024
# 9            10.0           Apoorv  22.0       M    DTU  11/12/2024
# 10           11.0       Kalicharan  33.0       M    DTU  10/12/2024
# 11           12.0           Akshit  21.0       M    DTU  10/12/2024
# ...

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               9
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 1
# Influenced_Others           1
# Media_Influence             1
# dtype: int64

# %%
df["Helmet_Type"] = df["Helmet_Type"].fillna("Unknown")

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df["Gender "].unique()
# Out:
# array(['M', 'F', nan], dtype=object)

# %%
df["Gender "] = (df["Gender "].str.lower().str.strip())

# %%
df["Gender "] = df["Gender "].replace({'m':'Male','f':'Female','nan':'NA'})

# %%
df["Helemt_Frequency"].unique()
# Out:
# array(['Always', 'Sometime', 'When Needed', nan], dtype=object)

# %%
df["Helemt_Frequency"] = (df["Helemt_Frequency"].str.capitalize())

# %%
df["Age"].dtype
# Out:
# dtype('float64')

# %%
df["Age"] = pd.to_numeric(df["Age"],errors="coerce")

# %%
def age_group(age):

    if age <=20:
        return "18-20"

    elif age <=25:
        return "21-25"

    else:
        return "26+"


df["Age_Group"] = df["Age"].apply(age_group)

# %%
df.head()
# Out:
#    Respondent_ID            Name   Age Gender  Place         Date  \
# 0            1.0    Govind Yadav  19.0       m    DTU  10/12/2024
# 1            2.0          Bhavya  20.0       m    DTU  10/12/2024
# 2            3.0  Abhishek Kumar  21.0       m    DTU  11/12/2024
# 3            4.0         Gupreet  20.0       m    DTU  10/12/2024
# 4            5.0    Mayank Yadav  21.0       m    DTU  10/12/2024
#
#     Safety_Device Helemt_Frequency Most_Vulnerable_User ISI_Awareness  \
# 0             NaN           Always          Two Wheeler            No
# 1  Quality Helmet         Sometime          Two Wheeler            No
# 2  Quality Helmet           Always          Two Wheeler            No
# 3  Quality Helmet           Always          Two Wheeler            No
# 4             NaN           Always          Two Wheeler            No
#
#   Youth_Role Speed_Limit_Knowledge Helmet_Prevention_belief  \
# 0        Yes               25 KMPH                       No
# ...

# %%
df.head()
# Out:
#    Respondent_ID            Name   Age Gender  Place         Date  \
# 0            1.0    Govind Yadav  19.0    Male    DTU  10/12/2024
# 1            2.0          Bhavya  20.0    Male    DTU  10/12/2024
# 2            3.0  Abhishek Kumar  21.0    Male    DTU  11/12/2024
# 3            4.0         Gupreet  20.0    Male    DTU  10/12/2024
# 4            5.0    Mayank Yadav  21.0    Male    DTU  10/12/2024
#
#     Safety_Device Helemt_Frequency Most_Vulnerable_User ISI_Awareness  \
# 0             NaN           Always          Two Wheeler            No
# 1  Quality Helmet         Sometime          Two Wheeler            No
# 2  Quality Helmet           Always          Two Wheeler            No
# 3  Quality Helmet           Always          Two Wheeler            No
# 4             NaN           Always          Two Wheeler            No
#
#   Youth_Role Speed_Limit_Knowledge Helmet_Prevention_belief  \
# 0        Yes               25 KMPH                       No
# ...

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               9
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 0
# Influenced_Others           1
# Media_Influence             1
# Age_Group                   0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Respondent_ID          Name   Age Gender  Place         Date  \
# 0             1.0  Govind Yadav  19.0    Male    DTU  10/12/2024
# 4             5.0  Mayank Yadav  21.0    Male    DTU  10/12/2024
# 5             6.0       Nikshep  23.0    Male    DTU  10/12/2024
# 8             9.0        Kalash  23.0    Male    DTU  11/12/2024
# 10           11.0    Kalicharan  33.0    Male    DTU  10/12/2024
# 22           23.0        Gaurav  21.0    Male    DTU  11/12/2024
# 33           34.0        Saumik  20.0    Male    DTU  10/12/2024
# 42           43.0         Jatin  20.0    Male    DTU  10/12/2024
# 45            NaN           NaN   NaN     NaN    NaN         NaN
#
#    Safety_Device Helemt_Frequency Most_Vulnerable_User ISI_Awareness  \
# 0            NaN           Always          Two Wheeler            No
# 4            NaN           Always          Two Wheeler            No
# 5            NaN           Always             Cyclists            No
# ...

# %%
df.tail()
# Out:
#     Respondent_ID      Name   Age Gender  Place         Date   Safety_Device  \
# 41           42.0  Anshuman  21.0    Male    DTU  10/12/2024  Quality Helmet
# 42           43.0     Jatin  20.0    Male    DTU  10/12/2024             NaN
# 43           44.0     Rahul  20.0    Male    DTU  10/12/2024  Quality Helmet
# 44           45.0    Akshat  20.0    Male    DTU  10/12/2024  Quality Helmet
# 45            NaN       NaN   NaN     NaN    NaN         NaN             NaN
#
#    Helemt_Frequency Most_Vulnerable_User ISI_Awareness Youth_Role  \
# 41           Always             Cyclists           Yes        Yes
# 42      When needed           Car Driver            No        Yes
# 43           Always          Two Wheeler           Yes        Yes
# 44         Sometime          Two Wheeler           Yes        Yes
# 45              NaN                  NaN           NaN        NaN
#
#    Speed_Limit_Knowledge Helmet_Prevention_belief Helmet_Buying_Factor  \
# ...

# %%
df.dropna(how="all",inplace=True)

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               9
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 0
# Influenced_Others           1
# Media_Influence             1
# Age_Group                   0
# dtype: int64

# %%
df[df["Safety_Device"].isnull()]
# Out:
#     Respondent_ID          Name   Age Gender  Place         Date  \
# 0             1.0  Govind Yadav  19.0    Male    DTU  10/12/2024
# 4             5.0  Mayank Yadav  21.0    Male    DTU  10/12/2024
# 5             6.0       Nikshep  23.0    Male    DTU  10/12/2024
# 8             9.0        Kalash  23.0    Male    DTU  11/12/2024
# 10           11.0    Kalicharan  33.0    Male    DTU  10/12/2024
# 22           23.0        Gaurav  21.0    Male    DTU  11/12/2024
# 33           34.0        Saumik  20.0    Male    DTU  10/12/2024
# 42           43.0         Jatin  20.0    Male    DTU  10/12/2024
# 45            NaN           NaN   NaN     NaN    NaN         NaN
#
#    Safety_Device Helemt_Frequency Most_Vulnerable_User ISI_Awareness  \
# 0            NaN           Always          Two Wheeler            No
# 4            NaN           Always          Two Wheeler            No
# 5            NaN           Always             Cyclists            No
# ...

# %%
df["Safety_Device"] = df["Safety_Device"].fillna("Not Mentioned")

# %%
df["Safety_Device"].value_counts()
# Out:
# Safety_Device
# Quality Helmet    37
# Not Mentioned      9
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               0
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 0
# Influenced_Others           1
# Media_Influence             1
# Age_Group                   0
# dtype: int64

# %%
df[df.isnull().all(axis=1)]
# Out:
# Empty DataFrame
# Columns: [Respondent_ID, Name, Age, Gender , Place , Date, Safety_Device, Helemt_Frequency, Most_Vulnerable_User, ISI_Awareness, Youth_Role, Speed_Limit_Knowledge, Helmet_Prevention_belief, Helmet_Buying_Factor, Pillion_Helmet, Mirror_Importance, Helmet_Type, Influenced_Others, Media_Influence, Age_Group]
# Index: []

# %%
df.dropna(
    how="all",
    inplace=True
)

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               0
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 0
# Influenced_Others           1
# Media_Influence             1
# Age_Group                   0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Respondent_ID Name  Age Gender  Place  Date  Safety_Device  \
# 45            NaN  NaN  NaN     NaN    NaN  NaN  Not Mentioned
#
#    Helemt_Frequency Most_Vulnerable_User ISI_Awareness Youth_Role  \
# 45              NaN                  NaN           NaN        NaN
#
#    Speed_Limit_Knowledge Helmet_Prevention_belief Helmet_Buying_Factor  \
# 45                   NaN                      NaN                  NaN
#
#    Pillion_Helmet Mirror_Importance Helmet_Type Influenced_Others  \
# 45            NaN               NaN     Unknown               NaN
#
#    Media_Influence Age_Group
# 45             NaN       26+

# %%
df = df.dropna(how="all")

# %%
df.shape
# Out:
# (46, 20)

# %%
df.isnull().sum()
# Out:
# Respondent_ID               1
# Name                        1
# Age                         1
# Gender                      1
# Place                       1
# Date                        1
# Safety_Device               0
# Helemt_Frequency            1
# Most_Vulnerable_User        1
# ISI_Awareness               1
# Youth_Role                  1
# Speed_Limit_Knowledge       1
# Helmet_Prevention_belief    1
# Helmet_Buying_Factor        1
# Pillion_Helmet              1
# Mirror_Importance           1
# Helmet_Type                 0
# Influenced_Others           1
# Media_Influence             1
# Age_Group                   0
# dtype: int64

# %%
df[df.isnull().any(axis=1)]
# Out:
#     Respondent_ID Name  Age Gender  Place  Date  Safety_Device  \
# 45            NaN  NaN  NaN     NaN    NaN  NaN  Not Mentioned
#
#    Helemt_Frequency Most_Vulnerable_User ISI_Awareness Youth_Role  \
# 45              NaN                  NaN           NaN        NaN
#
#    Speed_Limit_Knowledge Helmet_Prevention_belief Helmet_Buying_Factor  \
# 45                   NaN                      NaN                  NaN
#
#    Pillion_Helmet Mirror_Importance Helmet_Type Influenced_Others  \
# 45            NaN               NaN     Unknown               NaN
#
#    Media_Influence Age_Group
# 45             NaN       26+

# %%
pd.set_option('display.max_columns', None)

df[df.isnull().any(axis=1)]
# Out:
#     Respondent_ID Name  Age Gender  Place  Date  Safety_Device  \
# 45            NaN  NaN  NaN     NaN    NaN  NaN  Not Mentioned
#
#    Helemt_Frequency Most_Vulnerable_User ISI_Awareness Youth_Role  \
# 45              NaN                  NaN           NaN        NaN
#
#    Speed_Limit_Knowledge Helmet_Prevention_belief Helmet_Buying_Factor  \
# 45                   NaN                      NaN                  NaN
#
#    Pillion_Helmet Mirror_Importance Helmet_Type Influenced_Others  \
# 45            NaN               NaN     Unknown               NaN
#
#    Media_Influence Age_Group
# 45             NaN       26+

# %%
df.loc[45]
# Out:
# Respondent_ID                         NaN
# Name                                  NaN
# Age                                   NaN
# Gender                                NaN
# Place                                 NaN
# Date                                  NaN
# Safety_Device               Not Mentioned
# Helemt_Frequency                      NaN
# Most_Vulnerable_User                  NaN
# ISI_Awareness                         NaN
# Youth_Role                            NaN
# Speed_Limit_Knowledge                 NaN
# Helmet_Prevention_belief              NaN
# Helmet_Buying_Factor                  NaN
# Pillion_Helmet                        NaN
# Mirror_Importance                     NaN
# Helmet_Type                       Unknown
# Influenced_Others                     NaN
# Media_Influence                       NaN
# Age_Group                             26+
# Name: 45, dtype: object

# %%
df = df[df["Respondent_ID"].notna()]

# %%
df.shape
# Out:
# (45, 20)

# %%
df.isnull().sum()
# Out:
# Respondent_ID               0
# Name                        0
# Age                         0
# Gender                      0
# Place                       0
# Date                        0
# Safety_Device               0
# Helemt_Frequency            0
# Most_Vulnerable_User        0
# ISI_Awareness               0
# Youth_Role                  0
# Speed_Limit_Knowledge       0
# Helmet_Prevention_belief    0
# Helmet_Buying_Factor        0
# Pillion_Helmet              0
# Mirror_Importance           0
# Helmet_Type                 0
# Influenced_Others           0
# Media_Influence             0
# Age_Group                   0
# dtype: int64

# %%
df.to_csv(
"LnT_Helmet_Survey_Cleaned.csv",
index=False
)
